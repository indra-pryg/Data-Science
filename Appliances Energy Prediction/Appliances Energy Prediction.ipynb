# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
ls
# Out:
# archive_14/  archive_14.zip  tes1.ipynb  Tes.ipynb

# %%
cd archive_14/
# Out:
# /home/ndr/Dokumen/DGS/Latihan/Python/Challenge 3/archive_14

# %%
ls
# Out:
# KAG_energydata_complete.csv

# %%
p = "KAG_energydata_complete.csv"
df = pd.read_csv(p)
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.tail()
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4  ...    T9     RH_9  \
# 19730  25.890000  42.025714  27.200000  41.163333  24.7  ...  23.2  46.7900
# 19731  25.754000  42.080000  27.133333  41.223333  24.7  ...  23.2  46.7900
# 19732  25.628571  42.768571  27.050000  41.690000  24.7  ...  23.2  46.7900
# 19733  25.414000  43.036000  26.890000  41.290000  24.7  ...  23.2  46.8175
# 19734  25.264286  42.971429  26.823333  41.156667  24.7  ...  23.2  46.8450
#
#            T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# ...

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df[df['Appliances'] == 1080]
# Out:
#                    date  Appliances  lights     T1       RH_1     T2   RH_2  \
# 731 2016-01-16 18:50:00        1080      30  21.93  42.766667  21.04  38.08
#
#        T3       RH_3     T4  ...     T9     RH_9     T_out  Press_mm_hg  \
# 731  20.7  40.633333  20.89  ...  17.79  40.6725  2.083333   765.033333
#
#      RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 731    85.5   3.666667        40.0  -0.083333  27.408521  27.408521
#
# [1 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  datetime64[ns]
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
col_date = ['date']
col_applience = ['Appliances']
col_lights = ['lights']
col_temp = ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9']
col_humadity = ['RH_1', 'RH_2', 'RH_3', 'RH_4', 'RH_5', 'RH_6', 'RH_7', 'RH_8', 'RH_9']
col_rand = ['rv1', 'rv2']
col_weather = ["T_out", "Tdewpoint","RH_out","Press_mm_hg","Windspeed","Visibility"]
col_light = ["lights"]

# %%
feature_var = df[col_temp + col_humadity + col_weather + col_light + col_rand]
target_var = df[col_applience]

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.hist(bins=20, figsize=(14, 17))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f25885a7fa0>,
# ...
#       dtype=object)

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df.head()
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df[col_applience].describe()
# Out:
#          Appliances
# count  19735.000000
# mean      97.694958
# std      102.524891
# min       10.000000
# 25%       50.000000
# 50%       60.000000
# 75%      100.000000
# max     1080.000000

# %%
f, ax = plt.subplots(2,2,figsize=(12,8))
vis1 = sns.distplot(df["RH_6"],bins=10, ax= ax[0][0])
vis2 = sns.distplot(df["RH_out"],bins=10, ax=ax[0][1])
vis3 = sns.distplot(df["Visibility"],bins=10, ax=ax[1][0])
vis4 = sns.distplot(df["Windspeed"],bins=10, ax=ax[1][1])

# %%
f = plt.figure(figsize=(12,5))
plt.xlabel('Appliance consumption in Wh')
plt.ylabel('Frequency')
sns.distplot(df[col_applience] , bins=10 ) ;

# %%
df.corr()
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df['Appliances'].duplicated().value_counts()
# Out:
# True     19643
# False       92
# Name: Appliances, dtype: int64

# %%
import matplotlib as mpl

df[col_temp].plot(kind='line', figsize=(15,10))
plt.figure(figsize=(15,10))

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.iloc[:, 1:].corr(), annot=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(feature_var, target_var, test_size = 0.25, random_state = 40)

# %%
print(X_test.shape)
print(y_test.shape)
print("")
print(X_train.shape)
print(y_train.shape)
# Out:
# (4934, 27)
# (4934, 1)
#
# (14801, 27)
# (14801, 1)

# %%
X_train.drop(["rv1","rv2","Visibility","T6","T9"], axis=1, inplace=True)
X_test.drop(["rv1","rv2","Visibility","T6","T9"], axis=1, inplace=True)
# Out:
# /home/ndr/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train_x = sc.fit_transform(X_train)
X_test_x = sc.fit_transform(X_test)
y_train_y = sc.fit_transform(y_train)
y_test_y = sc.fit_transform(y_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
#import xgboost as xgb
from sklearn import neighbors
from sklearn.svm import SVR

# %%
model_knn = neighbors.KNeighborsRegressor()
model_knn.fit(X_train_x, y_train_y)
y_pred_knn = model_knn.predict(X_test_x)
y_pred_knn
# Out:
# array([[ 0.42909691],
#        [ 0.97318341],
#        [-0.56191778],
#        ...,
#        [-0.44532781],
#        [-0.52305446],
#        [-0.5036228 ]])

# %%
print(r2_score(y_test_y, y_pred_knn))
print(mean_absolute_error(y_test_y, y_pred_knn))
print(mean_squared_error(y_test_y, y_pred_knn))
# Out:
# 0.4380205825507957
# 0.3458799279186052
# 0.5619794174492043

# %%
model_svr = SVR(kernel='rbf')
model_svr.fit(X_train_x, y_train_y)
y_pred_svr = model_knn.predict(X_test_x)
# Out:
# /home/ndr/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
model_rf = RandomForestRegressor(n_estimators=100)
model_rf.fit(X_train_x, y_train_y)
y_pred_rf = model_rf.predict(X_test_x)
# Out:
# <ipython-input-43-a1dddf9678f0>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_rf.fit(X_train_x, y_train_y)

# %%
model_ETR = ExtraTreesRegressor()
model_ETR.fit(X_train_x, y_train_y)
y_pred_ETR = model_ETR.predict(X_test_x)
# Out:
# <ipython-input-45-e47141cf14b4>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_ETR.fit(X_train_x, y_train_y)

# %%
model_MLR = MLPRegressor(activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)
model_MLR.fit(X_train_x, y_train_y)
y_pred_MLR = model_MLR.predict(X_test_x)
# Out:
# /home/ndr/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
a1 = r2_score(y_test_y, y_pred_knn)
a2 = r2_score(y_test_y, y_pred_MLR)
a3 = r2_score(y_test_y, y_pred_ETR)
a4 = r2_score(y_test_y, y_pred_rf) 
a5 = r2_score(y_test_y, y_pred_svr)

b1 = mean_absolute_error(y_test_y, y_pred_knn)
b2 = mean_absolute_error(y_test_y, y_pred_MLR)
b3 = mean_absolute_error(y_test_y, y_pred_ETR)
b4 = mean_absolute_error(y_test_y, y_pred_rf) 
b5 = mean_absolute_error(y_test_y, y_pred_svr)

c1 = mean_squared_error(y_test_y, y_pred_knn)
c2 = mean_squared_error(y_test_y, y_pred_MLR)
c3 = mean_squared_error(y_test_y, y_pred_ETR)
c4 = mean_squared_error(y_test_y, y_pred_rf) 
c5 = mean_squared_error(y_test_y, y_pred_svr)

R2_s = [a1, a2, a3, a4, a5]
m_a_e = [b1, b2, b3, b4, b5]
m_s_e = [c1, c2, c3, c4, c5]

# %%
print(R2_s)
print(m_a_e)
print(m_s_e)
# Out:
# [0.4380205825507957, 0.2319174854007272, 0.5747598429309869, 0.5187848888295779, 0.4380205825507957]
# [0.3458799279186052, 0.46919647331551745, 0.303858675260326, 0.3356440413509806, 0.3458799279186052]
# [0.5619794174492043, 0.7680825145992728, 0.4252401570690131, 0.48121511117042215, 0.5619794174492043]
